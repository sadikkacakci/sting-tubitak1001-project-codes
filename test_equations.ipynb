# %%
from dummy_data_generator import DummyDataGenerator
from equations import ModelEquations
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
# Out:
# c:\Users\Sadık\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
treatment_process = 90 # tedavi süreci
number_of_patients = 12 # hasta sayısı
generator = DummyDataGenerator(treatment_process,number_of_patients)

# %%
data = generator.get_dummy_data()

# %%
patients = data["Patient_ID"].unique()
patients
# Out:
# array([1000, 1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010,
#        1011], dtype=int64)

# %%
patient_data = data.loc[data["Patient_ID"] == 1002]

# %%
model_equations = ModelEquations(patient_data)

# %%
model_equations.apply_6mp_model()
model_equations.plot_6_mp_model_solutions()

# %%
model_equations.apply_mtx_model()
model_equations.plot_mtx_model_solutions()
